# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load (Remember to Change These)
yelp_data_to_load = "data/PyRestaurants_data.csv"

# %%
school_df = pd.read_csv(yelp_data_to_load)
school_df
# Out:
#                           id                    name         phone  \
# 0     6i7KnRylm4bhPIApDFSVCg      Dave's Hot Chicken  1.323537e+10
# 1     fxeuGYnoRWwm5aGDg1FRJA          Marugame Monzo  1.213347e+10
# 2     qAAoilHU25Qr45FOQlA19g  Kang Ho-dong Baekjeong  1.213385e+10
# 3     DJek3FUewBzMc0gS-Gms9w            The Morrison  1.323667e+10
# 4     oMWttbTso0Mh_aIDIAFToQ                   Amboy  1.213936e+10
# ...                      ...                     ...           ...
# 3526  5nsiiMXiNR7ET7ZYJTtAgg                    IHOP  1.925228e+10
# 3527  USmXENBdqmR1cInAX33_AQ         Jack in the Box  1.707751e+10
# 3528  B2aWkrXr4Eb4r5TxOffE5g                    IHOP  1.925687e+10
# 3529  nAKKAXMfFSIDI_SyMXlKHw              McDonald's  1.925370e+10
# 3530  UXqdHXaa17ufXLkGck99Fg              McDonald's  1.925357e+10
#
#            location.address1 location.address2  location.city  \
# 0          970 N Western Ave               NaN    Los Angeles
# ...
